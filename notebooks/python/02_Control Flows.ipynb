# %% [markdown]
# ## Python Control Flows

# %%
# if statement

val=input("Enter the number ")
value_float=float(val)
if(value_float%2==0):
    print("the number is even")
# Out:
# the number is even

# %%
10%2!=0
# Out:
# False

# %%
# if- else statement

val=input("Enter the number ")
value_float=float(val)
if(value_float%2==0):
    print("the number is even")
else:
    print("The number is odd")
# Out:
# The number is odd

# %%
## Age form
##nested if else condition

age=float(input("Enter the age"))

if(age<18):
    print("Minor Age")
elif(age>=18 and age<=45):
    print("Mid Age")
elif(age>45 and age<=50):
    print("Senior Mid Age")
else: 
    print("Senior Citizen")
# Out:
# Minor Age

# %%
# nested iflese


age=float(input("Enter the age"))

if(age<18):
    print("Minor Age")
    if(age<15):
        print("You are in School")
    else:
        print("You are in College")
elif(age>=18 and age<=45):
    print("Mid Age")
elif(age>45 and age<=50):
    print("Senior Mid Age")
else: 
    print("Senior Citizen")
# Out:
# Mid Age

# %%
## Loops statement
## for loop, while loop
lst=[1,2,3,4,5,6,7]
for i in lst:
    print(i**2)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49

# %%
##find the sum of all the elements in the list
lst=[1,2,3,4,5,6,7]
sum1=0
for i in lst:
    sum1=sum1+i
    
print(sum1)
# Out:
# 28

# %%
## find the sum of even and odd number
lst=[1,2,3,4,5,6,7]
even_sum=0
odd_sum=0


for i in lst:
    if(i%2==0):
        even_sum=even_sum+i
    else:
        odd_sum=odd_sum+i
        
print("Even sum is {}".format(even_sum))
print("Odd sum is {}".format(odd_sum))
# Out:
# Even sum is 12
# Odd sum is 16

# %%
## while condition (As long as the condition is true, it will execute the block of code)

i=0
even_sum=0
odd_sum=0
while(i<=10):
    if(i%2==0):
        even_sum=even_sum+i
    else:
        odd_sum=odd_sum+i
    i=i+1
print(even_sum,odd_sum)
# Out:
# 30 25

# %%
##break (Terminates the loop when a certain condition is met)
x=1
while(x<7):
    if x==4:
        break
    print(x)
    x=x+1
# Out:
# 1
# 2
# 3

# %%
## continue (Skips the rest of the code inside the loop for the current iteration and moves to the next iteration)
x=0
while x<7:
    x=x+1
    if x==4:
        continue
    print(x)
# Out:
# 1
# 2
# 3
# 5
# 6
# 7
