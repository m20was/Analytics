# %%
import pandas as pd

# Define data using a dictionary
data = {
    "age": [21, 24, 23, 26, 22],
    "category": ["AI", "Web", "AI", "Data", "Web"],
    "score": [95, 80, 88, 92, 75]
}

# Create the DataFrame
df = pd.DataFrame(data)

# View the contents
print("📊 Pandas DataFrame Created:")
print(df)
# Out:
# 📊 Pandas DataFrame Created:
#    age category  score
# 0   21       AI     95
# 1   24      Web     80
# 2   23       AI     88
# 3   26     Data     92
# 4   22      Web     75

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .master("local[1]") \
    .config("spark.driver.host", "127.0.0.1") \
    .config("spark.driver.bindAddress", "127.0.0.1") \
    .getOrCreate()

print("Permanent Success via .env!")
# Out:
# Permanent Success via .env!
